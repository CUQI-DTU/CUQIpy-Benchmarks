# %%
import cuqi
import numpy as np
import os
import sys
sys.path.append(os.path.abspath('..'))
# from utilities import TableAutomization as TA
import utilities
import benchmarksClass as BC 
import matplotlib.pyplot as plt

# %%
target_wolfgang = BC.Wolfgang()
x0 = BC.Wolfgang().x0
# Out:
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# WARNING: user expression has not supplied value_shape method or an element. Assuming scalar element.
# ...

# %%
samples = utilities.MCMCComparison(dim = 3, target= target_wolfgang, scale = [0.027,0.027,0.000233,0.000233,0.5], Ns = 800, Nb= 200, seed = 12,chains=3)

# %%
samples.create_comparison()
# Out:
# Sample 1000 / 1000
#
# Average acceptance rate: 0.6
#
# Sample 30 / 1000
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 samples.create_comparison()
#
# File ~/Desktop/CUQIpy_project/CUQIpy-Benchmarks/utilities/_mcmcComparison.py:185, in MCMCComparison.create_comparison(self)
#     165 """
#     166 Create a table comparing various sampling methods with ESS values.
#     167
#    (...)
#     181 plot : matplotlib figure, plot of the samples
#     182 """
#     184 # Run precomputation
# --> 185 samples, pr = self.precompute_samples(True)
#     186 df_dict ={}
#     187 for method in self.selected_methods:
#
# File ~/Desktop/CUQIpy_project/CUQIpy-Benchmarks/utilities/_mcmcComparison.py:123, in MCMCComparison.precompute_samples(self, save)
#     121 if method in method_mapping:
#     122     mcmc_method, adapted = method_mapping[method]
# ...
